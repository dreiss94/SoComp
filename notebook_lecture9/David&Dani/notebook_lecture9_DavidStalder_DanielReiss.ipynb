# %% [markdown]
# # Lecture 9

# %%
# Please inlcude your names below
# Also, please edit the name of the file and include the names of the two(or three) people answering

# Pair answering the assignment: Daniel Reiss, David Stalder
# Pair giving feedback: Ivan Allinckx, Chritian Aeberhard

# %% [markdown]
# ## Email Classification
# For this week’s exercise you are provided with a dataset of hashed email addresses. This dataset can be found in hashedEmailAddressesGitHubCommits.csv, at https://www.dropbox.com/s/kevcp917ok9qyn0/hashedEmailAddressesGitHubCommits.csv.zip?dl=0. Please make sure you can access this file.

# %% [markdown]
# ### 1. Identifying the country of residence
#
# Based on the email address, we can infer different properties about the user. One example is their country of residence. For example, an email like “1315ae6229444367968a943a219f38def9a8112d@vpn-251-169.epfl.ch” will probably correspond to a user located in Switzerland, while an email of the form “59bd0a3ff43b32849b319e645d4798d8a5d1e889@philipphauer.de” will probably correspond to a user located in Germany.
#
# 1. Write a script that classifies the email addresses based on the country of residence.

# %%
import csv


with open("hashedEmailAddressesGitHubCommits.csv", "r", encoding="utf8") as file:
    csv_file_reader = csv.reader(file)
    
    mail_dict = {}
    
    for row in csv_file_reader:
        ending = row[0].split('.')[-1]
        if ending in mail_dict.keys():
            mail_dict[ending].append(row[0])
        else:
            mail_dict[ending]= [row[0]]
    
    print(mail_dict.keys())
# Out:
# dict_keys(['com', 'jp', 'io', 'ch', 'nl', 'in', 'edu', 'org', '8eed33e2dc1abf380eeb2fc3364dc2954aa4bfae@DESKTOP-F7F9K18', 'ru', 'cn', 'de', 'fr', 'be', 'local', 'tr', 'uk', 'tv', 'at', 'mx', 'net', 'au', 'pt', 'localdomain', 'ca', 'lt', 'cz', 'team', 'ai', 'bg', 'f61e6c1544a696c99cf0491dfab19d042c5d37c1', 'gov', '0b2fa2642da61ef6649696668e500b4dd6383bca@I107-05', 'space', 'somani05', 'one', 'me', '4bc4a41a2e092ac6c7523078813f9cae588ab1a8@DESKTOP-8UPOFGM', 'es', 'internal', 'CA', '(none)', 'com”', 'b03fe988f8d55b87dbd2223ee1a8a37a0f882d6e@homestead', 'pro', 'pl', '185', 'se', 'br', 'info', 'eu', 'rs', 'com]', 'COM', 'ph', 'hk', 'biz', 'cc', 'kr', 'al', 'catalogue', 'ninja', 'co', 'nz', 'cat', 'fd718bc6678319d159bb9b9b7b978ef5012742e1', 'tw', 'by', 'fi', '39469b3d9d3252717c8f08e5219375c891620fbc', 'it', '0cca2b1485668b599bdf5ebfd4b61c417d02dd2c', 'df68443e7d59e35b4692bbd18d401aa9ac43b7a8', '6d91a2e627dbd2b0ba63977d90998744dbfc095d', 'th', 'run', 'ca01f90215916bf61f7bdced05b55c9adfc6507a', '23d4fad18003f10a9a5bd6786d33ed7debb8e359', 'email', '04eeccd3a3025e14acabc1aa3a36375d1de1a9ee', '73f03d03f6af2871e791baaebc5c217d00459ac3@DESKTOP-29CVHPG', '6c51009eabcfb6bb52dd548b54881806756212d7@SPAERO', '77cccf0d7a72ee
f71930622ba43eacf3', '1942eccb3cae1891ea2502ac5c5aad4ad8e55b0c', '1830e9168f6e1e831b1d2d208bd3f31ebe7b5a51', '6ddea9da00b4a0d54800fe2c827b1a978d475ccf@Antoine', '1bfb56b6bb325aaa42d3631578b92d308f3f1c1e@b7066ec8-a400-4ec7-5d0e-19cf', 'ar', '054b8a97845b86a485ee89beb31ff3447379e38c@marco', 'ee', 'ro', '37531a68bcb52c1dbc37288f136280d59dbb18a6@YI-XIONG', 'LAN', 'rw', 'ltd', 'fake', '7be85dd89486a30909f46f4bd681c1a5a048fb2c@PC30', 'gy', 'lv', '929ccea168c20626f12cdeee4a67a2b77086571b', 'host', 'aff1e1c3afc138672ba4dc4fee2f4643aebedec0@VW-WIN10-DEV', 'f70e95cb88b287c2df753b613 ...

# %% [markdown]
# 2. Select 100 email addresses from the list. Each member of the team should manually evaluate them (separately).

# %%
# Please put the name of the first pair-member doing the evaluation below
# NAME: Dani

# Your evaluation for the 100 emails goes below

with open("hashedEmailAddressesGitHubCommits.csv", "r", encoding="utf8") as file:
    csv_file_reader = csv.reader(file)
    
    count = 0
    for row in csv_file_reader:
        if count < 100:
            print(row[0].split('.')[-1] + '\t' + row[0])
            count += 1
        else:
            break
# Out:
# com	9fd8de5fc2a7c2c0d469b2fff1afde4e5def37ba@georgemcintosh.com
# com	229de65f28dfbfbe8eeed5e512ab772e573e891a@gmail.com
# com	869a92ca579ecfd79c8d4f27a1fc29f47d2b6b84@kitconcept.com
# jp	f0ed5cc04491838daa1cd1ee171dabd3e0309500@cpc.ait.kyushu-u.ac.jp
# com	1a66a945a7c848e2e3f1cd5f9692be1f16a0a484@users.noreply.github.com
# com	4908d22f1783df5f426e6457fd1f33885cace923@users.noreply.github.com
# com	9cc72b55642e601704f4935b8cccd6ac02774cc8@users.noreply.github.com
# com	08cb1275375b04cbfb985246da98a353e45ee73b@users.noreply.github.com
# io	a9e176775387607c240830b2b262fd73e9ce1af4@nuco.io
# com	d800962b1449d7d424cf379aa077f7eab3bf1639@gmail.com
# com	a95d7959e5fe57bb7d0f6e8d9eaa54f5c13a966e@gmail.com
# com	23fb0a88e049b7ae8b76494f2246a0f5841d49ea@naver.com
# com	19801b77c957f88583c17f6fae667f7ec052de6c@icometrix.com
# com	481c6dba6175141e6ed9fa18883f090f3e61f30a@users.noreply.github.com
# com	492eaf80557a39619f4731b34ad9b0589827ad30@users.noreply.github.com
# ch	1315ae6229444367968a943a219f38def9a8112d@vpn-251-169.epfl.ch
# com	b5d0caa2de2b3461e49435381a99ba6fe39ca708@gmail.com
# nl	bd2e69024a9262bb6248690ae524a4b9b6151fba@evalf.nl
# com	f393b2660462486bf236c387d82df268f4b768da@users.noreply.github.com
# com	456bf22f95957abbe628a42b2314d9cd5318493f@users.noreply.github.com
# com	3c840b7fbf9e32ed65f739ab5f905b98dae7ca9a@gmail.com
# com	d3b170102c5da65c08d2b32c5e9679b55c54dfa6@gmail.com
# com	620ec65f884440cd83b20a92e0223299847e88d7@gmail.com

# %%
# Please put the name of the second pair-member doing the evaluation below
# NAME: David

# Your evaluation for the 100 emails goes below

with open("hashedEmailAddressesGitHubCommits.csv", "r", encoding="utf8") as file:
    csv_file_reader = csv.reader(file)
    
    count = 100
    for row in csv_file_reader:
        if count < 200:
            print(row[0].split('.')[-1] + '\t' + row[0])
            count += 1
        else:
            break
# Out:
# com	9fd8de5fc2a7c2c0d469b2fff1afde4e5def37ba@georgemcintosh.com
# com	229de65f28dfbfbe8eeed5e512ab772e573e891a@gmail.com
# com	869a92ca579ecfd79c8d4f27a1fc29f47d2b6b84@kitconcept.com
# jp	f0ed5cc04491838daa1cd1ee171dabd3e0309500@cpc.ait.kyushu-u.ac.jp
# com	1a66a945a7c848e2e3f1cd5f9692be1f16a0a484@users.noreply.github.com
# com	4908d22f1783df5f426e6457fd1f33885cace923@users.noreply.github.com
# com	9cc72b55642e601704f4935b8cccd6ac02774cc8@users.noreply.github.com
# com	08cb1275375b04cbfb985246da98a353e45ee73b@users.noreply.github.com
# io	a9e176775387607c240830b2b262fd73e9ce1af4@nuco.io
# com	d800962b1449d7d424cf379aa077f7eab3bf1639@gmail.com
# com	a95d7959e5fe57bb7d0f6e8d9eaa54f5c13a966e@gmail.com
# com	23fb0a88e049b7ae8b76494f2246a0f5841d49ea@naver.com
# com	19801b77c957f88583c17f6fae667f7ec052de6c@icometrix.com
# com	481c6dba6175141e6ed9fa18883f090f3e61f30a@users.noreply.github.com
# com	492eaf80557a39619f4731b34ad9b0589827ad30@users.noreply.github.com
# ch	1315ae6229444367968a943a219f38def9a8112d@vpn-251-169.epfl.ch
# com	b5d0caa2de2b3461e49435381a99ba6fe39ca708@gmail.com
# nl	bd2e69024a9262bb6248690ae524a4b9b6151fba@evalf.nl
# com	f393b2660462486bf236c387d82df268f4b768da@users.noreply.github.com
# com	456bf22f95957abbe628a42b2314d9cd5318493f@users.noreply.github.com
# com	3c840b7fbf9e32ed65f739ab5f905b98dae7ca9a@gmail.com
# in	085d380448c094a4ead4e3b94b7437d8142c0113@ves.ac.in
# edu	a6e2cda2c8c2bb5c707d3aaa1c286da1d4e339ad@ndus.edu
# com	5145e8b59245f3266c7edb93bcfa85be1bf730b2@users.noreply.github.com
# com	08ab783062ca8c8e24c198f5c0dc4e9acbd92213@gmail.com
# com	5f80adc06c9ff0cc6402f2ac8885cd5332cf5a59@users.noreply.github.com
# com	459a70b0c53f6300bb56703743c1d133735e5db0@gmail.com
# com	5bc12f4c2e63ba09e561a5e8411d6dca87515446@amazon.com
# com	364f82574d60f24ac6aa95409285f7132bf947df@gmail.com
# com	91b234a3692cf41b5b1b2157c5658810446e7b12@users.noreply.github.com
# org	64bd05d89142566144bce27f4904a322d8d9e836@enzy.org
# com	df863752181fe0b8ff2f51378005bfa29cffcacd@dg10a.com
local	63a5fd3bc5f45a0490e4deca178d288050e26803@Mac-1675.local
...

.local is not a valid domain for an email address


Therefore, we implemented an improved filter in order to catch these (and similar) special cases.

'''
# Out:
# '\nWe printed the first 200 addresses, discussed the output and came to the following conclusions:\n\nWe found some special cases:\n\n1)\n8eed33e2dc1abf380eeb2fc3364dc2954aa4bfae@DESKTOP-F7F9K18 \nThis is not a valid format for an email address, it has no domain\n\n2)\nlocal\tc2ec8be6d666e4ef2dfe363bdeaf6ba0f7d2e7fd@Israels-MacBook-Pro.local\nlocal\t5c2b569b6a1b361b39ebce796a7821d16ed262d0@MacBook-Pro-105.local\nlocal\t6543800a3f8e2fee20d758c9402e8a64fa13c47b@TXCDTVB6790ML01.local\nlocal\t63a5fd3bc5f45a0490e4deca178d288050e26803@Mac-1675.local\n...\n\n.local is not a valid domain for an email address\n\n\nTherefore, we implemented an improved filter in order to catch these (and similar) special cases.\n\n'

# %% [markdown]
# 4. Now, evaluate the coverage and the accuracy of your algorithm by comparing your labels with the algorithm's result.
#  -  Based on the random sample, what % of the data can your algorithm classify? Can you add something to your code to increase it? If, yes, include below your updated code. How much did coverage increase?
#  - Based on the classified items on your list, what % did your algorithm classify correctly?

# %%
with open("hashedEmailAddressesGitHubCommits.csv", "r", encoding="utf8") as file:
    csv_file_reader = csv.reader(file)
    
    mail_dict = {}
    
    for row in csv_file_reader:
        ending = row[0].split('.')[-1]
        if 'local' not in ending.lower() and ending.isalpha():
            if ending in mail_dict.keys():
                mail_dict[ending].append(row[0])
            else:
                mail_dict[ending]= [row[0]]
                
    print(mail_dict.keys())
# Out:
# dict_keys(['com', 'jp', 'io', 'ch', 'nl', 'in', 'edu', 'org', 'ru', 'cn', 'de', 'fr', 'be', 'tr', 'uk', 'tv', 'at', 'mx', 'net', 'au', 'pt', 'ca', 'lt', 'cz', 'team', 'ai', 'bg', 'gov', 'space', 'one', 'me', 'es', 'internal', 'CA', 'pro', 'pl', 'se', 'br', 'info', 'eu', 'rs', 'COM', 'ph', 'hk', 'biz', 'cc', 'kr', 'al', 'catalogue', 'ninja', 'co', 'nz', 'cat', 'tw', 'by', 'fi', 'it', 'th', 'run', 'email', 'vn', 'digital', 'ir', 'no', 'lan', 'is', 'aero', 'moe', 'Dlink', 'chat', 'ua', 'id', 'sk', 'hr', 'us', 'xyz', 'codes', 'za', 'here', 'gt', 'dk', 'box', 'pe', 'external', 'software', 'ie', 'sa', 'home', 'ng', 'AULAS', 'hpc', 'dz', 'EDU', 'cl', 'tech', 'lk', 'fm', 'dev', 'sg', 'ae', 'sarl', 'ar', 'ee', 'ro', 'LAN', 'rw', 'ltd', 'fake', 'gy', 'lv', 'host', 've', 'cx', 'ba', 'thing', 'my', 'tn', 'suse', 'COMPUTACAO', 'il', 'vip', 'technology', 'cum', 'comkaramanskyi', 'con', 'sh', 'SE', 'asia', 'cy', 'kh', 'si', 'pw', 'az', 'kim', 'link', 'comm', 'hu', 'studio', 'community', 'void', 'cloud', 'bd', 'global', 'zone', 'nu', 'su', 'build', 'money', 'int', 'cm', 'solar', 'name', 'mg', 'BrainHack', 'gg', 'aulas', 'mt', 'ovh', 'gr', 'site', 'nyc', 'ec', 'earth', 'works', 'lu', 'uy', 'address', 'life', 'coms', 'om', 'vc', 'campus', 'ede', 'engineer', 'nantes', 'fish', 'sv', 'private', 'ge', 'np', 'fair', 'station', 'am', 'cmo', 'comAccount', 'tokyo', 'rocks', 'eg', 'fun', 'vom', 'ml', 'systems', 'k', 'everist', 'online', 'tc', 'sandbox', 'loc', 'cr', 'pk', 'bcs', 'ao', 'jsc', 'im', 'werk', 'elecom', 'intranet', 'comt', 'world', 'development', 'do', 'coop', 'khp', 'health', 'love', 'ke', 'ma', 'SUNet', 'red', 'li', 'test', 'school', 'corp', 'insure', 'training', 'bi', 'sf', 'uz', 'SA', 'Fr', 'mynet', 'ws', 'berlin', 'consulting', 'comn', 'club', 'fds', 'ga', 'vdi', 'vet', 'domain', 'manje', 'mail', 'la', 'network', 'group', 'connectify', 'afpanet', 'broadband', 'computer', 'ain', 'industries', 'je', 'treina', 'DE', 'nova', 'dcx', 'intern', 'games', 'kn', 'app', 'work', 'comls', 'prd', 'ORG', 'ip', 'wang', 'gueler', 'vagrant', 'st', 'git', 'b', 'github', 'gs', 'bbrouter', 'coffee', 're', 'company', 'solutions', 'plus', 'lcom', 'Com', 'tz', 'bio', 'today', 'py', 'agency', 'BR', 'prometheus', 'antoine', 'RED', 'wtf', 'andre', 'TM', 'center', 'gloabl', 'media', 'mlnx', 'opt', 'marketing', 'engineering', 'rr', 'lb', 'itresources', 'coml', 'design', 'mv', 'icu', 'LCL', 'Home', 'bo', 'colo', 'NET', 'art', 'Biz', 'igrupobbva', 'ly', 'swtv', 'u', 'to', 'academy', 'foundation', 'taxi', 'guru', 'jo', 'md', 'jmc', 'GOB', 'DAFIP', 'intra', 'expert', 'enterprises', 'csb', 'hub', 'JNMOURA', 'okmt', 'IE', 'kz', 'ib', 'ccom', 'gh', 'z', 'ug', 'nc', 'core', 'comddd', 'kiwi', 'mobile', 'ms', 'os', 'mil', 'travel', 'ok', 'XX', 'coom', 'mu', 'root', 'nett', 'tu', 'RU', 'MY', 'xom', 'maas', 'dhote', 'grp', 'nauhpc', 'cpm', 'smb', 'frcls', 'mobi', 'Tn', 'comj', 'le', 'way', 'get', 'sag', 'UK', 'cpom', 'institute', 'green', 'hugyszalai', 'bet', 'science', 'Ca', 'christmas', 'bar', 'bz', 'live', 'jetpack', 'ubec', 'ht', 'pa', 'bike', 'africa', 'ag', 'GOV', 'cluster', 'modem', 'crumbs', 'family', 'ni', 'ooo', 'HU', 'builder', 'code', 'iol', 'EGIM', 'wales', 'sdnnfv', 'wlan', 'care', 'ci', 'clou', 'win', 'top', 'fortis', 'camp', 'trust', 'privat', 'wmflabs', 'ARXNET', 'ads', 'support', 'raft', 'eltech', 't', 'saarland', 'sc', 'bzh', 'g', 'dem', 'flights', 'mn', 'somosnet', 'harbringer', 'bullx', 'dal', 'pm', 'cash', 'dom', 'sn', 'vwg', 'ngo', 'study', 'ski', 'hn', 'eco', 'cim', 'comcd', 'cu', 'pri', 'das', 'tld', 'gateway', 'bot', 'finance', 'fit', 'comg', 'bayern', 'linux', 'PlumbLab', 'MAISON', 'direct', 'edx', 'hq', 'john', 'null', 'sncf', 'triana', 'pub', 'BH', 'weike', 'gf', 'tk', 'asuna', 'nt', 'kg', 'sopra', 'office', 'rostand', 'swiss', 'none', 'MX', 'netm', 'clm', 'cf', 'type', 'IMTI', 'fhnw', 'rg', 'msk', 'n', 'ink', 'paris', 'INT', 'security', 'coum', 'iam', 'financial', 'jjr', 'coach', 'Dev', 'press', 'llc', 'bf', 'energy', 'menu', 'pucmm', 'gold', 'lab ...

# %%
# Your analysis of coverage increase goes below
'''
Our updated code is 100% accurate for the first 200 addresses in the list. If we go further in the list, we cannot
guarantee this accuracy.
As a futher step we would need to verify if the remaining endings of the addresses are indeed valid domains.
'''
# Out:
# '\nOur updated code is 100% accurate for the first 200 addresses in the list. If we go further in the list, we cannot\nguarantee this accuracy.\nAs a futher step we would need to verify if the remaining endings of the addresses are indeed valid domains.\n'

# %% [markdown]
# The country of residence is not the only characteristic of the user that can be inferred from their email address.
# 5. Make a short list of other characteristics that you could infer from the data.

# %%
# Please list the other criteria below
'''
.edu indicates that the address is for educational purpose
.com commercial 
.gov for government use
.org organization
.net infrastructures
.mil military


Names and year of birth are often used in email addresses. However, this data should not be trusted, becauses it
can easily be faked.
'''
# Out:
# '\n.edu indicates that the address is for educational purpose\n.com commercial \n.gov for government use\n.org organization\n.net infrastructures\n.mil military\n\n\nNames and year of birth are often used in email addresses. However, this data should not be trusted, becauses it\ncan easily be faked.\n'

# %% [markdown]
# The last part of the exercise is optional. You can do it if you want to and have time, but it will not count towards the grade.
# 6. Repeat the classification in the previous part of the exercise for one alternative characteristic. For example, you could classify based on business vs educational vs private accounts, but feel free to use your own criteria.

# %%
# If you choose to do the last exercise, please include your code below

# %% [markdown]
# Congratulations for completing the fourth (and last) notebook! Now it’s time for feedback.
# 1.	Pass your solution to the other pair in your group.
# 2.	Include your feedback in the other pair’s notebook. Don’t forget to add your names at the top.
# 3.	Return the notebook with feedback to the original pairs.
# 4.	Upload your notebook, with the feedback included by the other pair on OLAT.
#
# You can think of/suggest (among other things)
#  - improvements in the code (e.g. readability, efficiency)
#  - improvements in the answers (e.g. are they easy to understand, are they correct, how can they be improved?)
#  - point out differences (e.g. are there any differences between the responses of the two pairs? if yes what are they, what is the cause, and in which way can they be useful?)
#
# Not all suggestions about the type of feedback apply to all types of questions. Try to give feedback in a meaningful and constructive way.

# %%
# Below there is space for giving feedback. This space should be used only by the other pair in your group.

'''
Feedback here
'''
# Out:
# '\nFeedback here\n'
